# %%
import pandas as pd  #Pandas.
import numpy as np  #Numpy
pd.set_option('display.max_columns', None) #que se vean todas las columnas una vez importado el documento.

import warnings  #que no salgan los warnings.
warnings.filterwarnings('ignore')

# %%
#Mi ruta  /Users/edgarahmed/Desktop/ironhack/semana_3/dia_5/proyecto_pelis/src/w3-project_SQL/data/rental.csv


df_ori= pd.read_csv ('/Users/edgarahmed/Desktop/ironhack/semana_3/dia_5/proyecto_pelis/data/rental.csv')
df_ori
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 0            1  2005-05-24 22:53:30           367          130
# 1            2  2005-05-24 22:54:33          1525          459
# 2            3  2005-05-24 23:03:39          1711          408
# 3            4  2005-05-24 23:04:41          2452          333
# 4            5  2005-05-24 23:05:21          2079          222
# ..         ...                  ...           ...          ...
# 995        997  2005-05-31 00:08:25          4243          216
# 996        998  2005-05-31 00:16:57          3395          389
# 997        999  2005-05-31 00:25:10          4433          413
# 998       1000  2005-05-31 00:25:56          1774          332
# 999       1001  2005-05-31 00:46:31          1498           64
#
#              return_date  staff_id          last_update
# 0    2005-05-26 22:04:30         1  2006-02-15 21:30:53
# 1    2005-05-28 19:40:33         1  2006-02-15 21:30:53
# ...

# %%
df = df_ori.copy()

df
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 0            1  2005-05-24 22:53:30           367          130
# 1            2  2005-05-24 22:54:33          1525          459
# 2            3  2005-05-24 23:03:39          1711          408
# 3            4  2005-05-24 23:04:41          2452          333
# 4            5  2005-05-24 23:05:21          2079          222
# ..         ...                  ...           ...          ...
# 995        997  2005-05-31 00:08:25          4243          216
# 996        998  2005-05-31 00:16:57          3395          389
# 997        999  2005-05-31 00:25:10          4433          413
# 998       1000  2005-05-31 00:25:56          1774          332
# 999       1001  2005-05-31 00:46:31          1498           64
#
#              return_date  staff_id          last_update
# 0    2005-05-26 22:04:30         1  2006-02-15 21:30:53
# 1    2005-05-28 19:40:33         1  2006-02-15 21:30:53
# ...

# %%
df.isna().all(axis=1).all()
# Out:
# False

# %%
df.isna().all(axis=0).all()
# Out:
# False

# %%
filas_duplis = df[["rental_id",'rental_date', 'inventory_id', 'customer_id', 'return_date', 'staff_id', 'last_update']]

# %%
filas_duplis[filas_duplis.duplicated()]
# Out:
# Empty DataFrame
# Columns: [rental_id, rental_date, inventory_id, customer_id, return_date, staff_id, last_update]
# Index: []

# %%
filas_duplis.duplicated().any()
# Out:
# False

# %%
df.drop(columns=['last_update'], inplace=True)


df
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 0            1  2005-05-24 22:53:30           367          130
# 1            2  2005-05-24 22:54:33          1525          459
# 2            3  2005-05-24 23:03:39          1711          408
# 3            4  2005-05-24 23:04:41          2452          333
# 4            5  2005-05-24 23:05:21          2079          222
# ..         ...                  ...           ...          ...
# 995        997  2005-05-31 00:08:25          4243          216
# 996        998  2005-05-31 00:16:57          3395          389
# 997        999  2005-05-31 00:25:10          4433          413
# 998       1000  2005-05-31 00:25:56          1774          332
# 999       1001  2005-05-31 00:46:31          1498           64
#
#              return_date  staff_id
# 0    2005-05-26 22:04:30         1
# 1    2005-05-28 19:40:33         1
# 2    2005-06-01 22:12:39         1
# 3    2005-06-03 01:43:41         2
# ...

# %%
#cargarme la columna de last_update y puede que las de return y rental date

#¿Cómo puede ser que haya un inventory ID en rental que sobrepasa el número 1000, cuando en inventory_ solo llega al 1000?

# %%
from sqlalchemy import create_engine

# %%
str_conn = f'mysql+pymysql://root:edgarahmed@localhost:3306/videoclub'

cursor = create_engine(str_conn)
print(cursor)
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/videoclub)

# %%
df.to_sql(name='rental_',       # nombre de la tabla
            con=cursor,           # conexion al servidor
            if_exists='replace',  # replace sobreescribe la tabla
            index=True
           )
# Out:
# 1000

# %%
df['inventory_id'].unique()
# Out:
# array([ 367, 1525, 1711, 2452, 2079, 2792, 3995, 2346, 2580, 1824, 4443,
#        1584, 2294, 2701, 3049,  389,  830, 3376, 1941, 3517,  146,  727,
#        4441, 3273, 3961, 4371, 1225, 4068,  611, 3744, 4482, 3832, 1681,
#        2613, 1286, 1308,  403, 2540, 4466, 2638, 1761,  380, 2578, 3098,
#        1853, 3318, 2211, 1780, 2965, 1983, 1257, 4017, 1255, 2787, 1139,
#        1352, 3938, 3050, 2884,  330, 4210,  261, 4008,   79, 3552, 1162,
#         239, 4029, 3207, 2168, 2408, 2260,  517, 1744, 3393, 3021, 1303,
#        4067, 3299, 2478, 2610, 1388,  466, 1829,  470, 2275, 1586, 2221,
#        2181, 2984,  139,  775, 4360, 1675,  178, 3418, 1283, 2970,  535,
#        2599,  617,  373, 3343, 4281,  794, 3627, 2833, 3289, 1044, 4108,
#        3725, 2153, 2963, 4502,  749, 4453, 4278,  872, 1359,   37, 1053,
#        2908, 1795,  212,  952, 2047, 2026, 4322, 4154, 3990,  815, 3367,
#         399, 2272,  103, 2296, 2591, 4134,  327,  655,  811, 4407,  847,
# ...

# %%
df = df[df['inventory_id'] <= 1000]  #me quito todos los valores por debajo de 1000, ya que no están en el inventario.

# %%
df
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 0            1  2005-05-24 22:53:30           367          130
# 15          16  2005-05-25 00:43:11           389          316
# 16          17  2005-05-25 01:06:36           830          575
# 20          21  2005-05-25 01:59:46           146          388
# 21          22  2005-05-25 02:19:23           727          509
# ..         ...                  ...           ...          ...
# 970        972  2005-05-30 20:21:07             2          411
# 976        978  2005-05-30 21:30:52           407          154
# 981        983  2005-05-30 22:15:51            63          115
# 985        987  2005-05-30 22:59:12           390           11
# 993        995  2005-05-31 00:06:02            17          150
#
#              return_date  staff_id
# 0    2005-05-26 22:04:30         1
# 15   2005-05-26 04:42:11         2
# 16   2005-05-27 00:43:36         1
# 20   2005-05-26 01:01:46         2
# ...

# %%
#Ahora me quedo solo con 212

# %%
#con rental date and return date seguro que se puede hacer algo similar a lo de crear un ratio, para ver cuanto venebicio da cada pelicula. esto estaría bien.

# %%
from sqlalchemy import create_engine

# %%
str_conn = f'mysql+pymysql://root:edgarahmed@localhost:3306/videoclub'
cursor = create_engine(str_conn)
print(cursor)
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/videoclub)

# %%
df.to_sql(name='rental',       # nombre de la tabla
            con=cursor,           # conexion al servidor
            if_exists='replace',  # replace sobreescribe la tabla
            index=True
           )
# Out:
# 212
