# %%
import pandas as pd  #Pandas.
import numpy as np  #Numpy
pd.set_option('display.max_columns', None) #que se vean todas las columnas una vez importado el documento.

import warnings  #que no salgan los warnings.
warnings.filterwarnings('ignore')

# %%
#mi ruta '/Users/edgarahmed/Desktop/ironhack/semana_3/dia_5/proyecto_pelis/src/w3-project_SQL/data/old_HDD.csv'

df_ori= pd.read_csv ('/Users/edgarahmed/Desktop/ironhack/semana_3/dia_5/proyecto_pelis/src/w3-project_SQL/data/old_HDD.csv')

df_ori
# Out:
#     first_name last_name                  title  release_year  category_id
# 0     PENELOPE   GUINESS       ACADEMY DINOSAUR          2006            6
# 1     PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006            2
# 2     PENELOPE   GUINESS            ANGELS LIFE          2006           13
# 3     PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4     PENELOPE   GUINESS          CHEAPER CLYDE          2006           14
# ..         ...       ...                    ...           ...          ...
# 995     GOLDIE     BRODY      COMANCHEROS ENEMY          2006            3
# 996     GOLDIE     BRODY        DAISY MENAGERIE          2006           14
# 997     GOLDIE     BRODY        DESERT POSEIDON          2006           11
# 998     GOLDIE     BRODY         EVERYONE CRAFT          2006            9
# 999     GOLDIE     BRODY         EXORCIST STING          2006           15
#
# [1000 rows x 5 columns]

# %%
df = df_ori.copy()

df
# Out:
#     first_name last_name                  title  release_year  category_id
# 0     PENELOPE   GUINESS       ACADEMY DINOSAUR          2006            6
# 1     PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006            2
# 2     PENELOPE   GUINESS            ANGELS LIFE          2006           13
# 3     PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4     PENELOPE   GUINESS          CHEAPER CLYDE          2006           14
# ..         ...       ...                    ...           ...          ...
# 995     GOLDIE     BRODY      COMANCHEROS ENEMY          2006            3
# 996     GOLDIE     BRODY        DAISY MENAGERIE          2006           14
# 997     GOLDIE     BRODY        DESERT POSEIDON          2006           11
# 998     GOLDIE     BRODY         EVERYONE CRAFT          2006            9
# 999     GOLDIE     BRODY         EXORCIST STING          2006           15
#
# [1000 rows x 5 columns]

# %%
df.isna().all(axis=1).all()
# Out:
# False

# %%
df[['first_name'].duplicated().any() ]
# Out:
# True

# %%
duplicated_values = df[df['first_name'].duplicated(keep=False)]['first_name'].tolist()

duplicated_values
# Out:
# ['PENELOPE',
#  'PENELOPE',
#  'PENELOPE',
#  'PENELOPE',
#  'PENELOPE',
#  'PENELOPE',
#  'PENELOPE',
#  'PENELOPE',
#  'PENELOPE',
#  'PENELOPE',
#  'PENELOPE',
#  'PENELOPE',
#  'PENELOPE',
#  'PENELOPE',
#  'PENELOPE',
#  'PENELOPE',
#  'PENELOPE',
#  'PENELOPE',
#  'PENELOPE',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'NICK',
#  'ED',
#  'ED',
#  'ED',
#  'ED',
#  'ED',
#  'ED',
#  'ED',
#  'ED',
#  'ED',
#  'ED',
#  'ED',
#  'ED',
#  'ED',
#  'ED',
#  'ED',
#  'ED',
#  'ED',
#  'ED',
#  'ED',
#  'ED',
#  'ED',
#  'ED',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JENNIFER',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'JOHNNY',
#  'BETTE',
#  'BETTE',
#  'BETTE',
#  'BETTE',
#  'BETTE',
#  'BETTE',
#  'BETTE',
#  'BETTE',
#  'BETTE',
#  'BETTE',
#  'BETTE',
#  'BETTE',
#  'BETTE',
#  'BETTE',
#  'BETTE',
#  'BETTE',
#  'BETTE',
#  'BETTE',
#  'BETTE',
#  'BETTE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'GRACE',
#  'MATTHEW',
#  'MATTHEW',
#  'MATTHEW',
#  'MATTHEW',
#  'MATTHEW',
#  'MATTHEW',
#  'MATTHEW',
#  'MATTHEW',
#  'MATTHEW',
#  'MATTHEW',
#  'MATTHEW',
#  'MATTHEW',
#  'MATTHEW',
#  'MATTHEW',
#  'MATTHEW',
#  'MATTHEW',
#  'MATTHEW',
#  'MATTHEW',
#  'MATTHEW',
#  'MATTHEW',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'JOE',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'CHRISTIAN',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'ZERO',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'KARL',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'UMA',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'VIVIEN',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'CUBA',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'FRED',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'HELEN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'DAN',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'BOB',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'LUCILLE',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'KIRSTEN',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'ELVIS',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'CAMERON',
#  'KEVIN',
#  'KEVIN',
#  'KEVIN',
#  'KEVIN',
#  'KEVIN',
#  'KEVIN',
#  'KEVIN',
#  'KEVIN',
#  'KEVIN',
#  'KEVIN',
#  'KEVIN',
#  'KEVIN',
#  'KEVIN',
#  'KEVIN',
#  'KEVIN',
#  'KEVIN',
#  'KEVIN',
#  'KEVIN',
#  'KEVIN',
#  'KEVIN',
#  'KEVIN',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'RIP',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'JULIA',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'WOODY',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'ALEC',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SANDRA',
#  'SISSY',
#  'SISSY',
#  'SISSY',
#  'SISSY',
#  'SISSY',
#  'SISSY',
#  'SISSY',
#  'SISSY',
#  'SISSY',
#  'SISSY',
#  'SISSY',
#  'SISSY',
#  'SISSY',
#  'SISSY',
#  'SISSY',
#  'SISSY',
#  'SISSY',
#  'SISSY',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'TIM',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'MILLA',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'AUDREY',
#  'JUDY',
#  'JUDY',
#  'JUDY',
#  'JUDY',
#  'JUDY',
#  'JUDY',
#  'JUDY',
#  'JUDY',
#  'JUDY',
#  'JUDY',
#  'JUDY',
#  'JUDY',
#  'JUDY',
#  'JUDY',
#  'JUDY',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'BURT',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'VAL',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'TOM',
#  'GOLDIE',
#  'GOLDIE',
#  'GOLDIE',
#  'GOLDIE',
#  'GOLDIE',
#  'GOLDIE',
#  'GOLDIE']

# %%
from sqlalchemy import create_engine

# %%
str_conn = f'mysql+pymysql://root:666666@localhost:3306/proyecto_pelis'

cursor = create_engine(str_conn)
print(cursor)
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/proyecto_pelis)

# %%
df.to_sql(name='old_HDD_',       # nombre de la tabla
            con=cursor,           # conexion al servidor
            if_exists='replace',  # replace sobreescribe la tabla
            index=True
           )
# Out:
# 1000
