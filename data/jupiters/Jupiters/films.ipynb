# %%
import pandas as pd  #Pandas.
import numpy as np  #Numpy
pd.set_option('display.max_columns', None) #que se vean todas las columnas una vez importado el documento.

import warnings  #que no salgan los warnings.
warnings.filterwarnings('ignore')

# %%
df_ori= pd.read_csv ('/Users/edgarahmed/Desktop/ironhack/semana_3/dia_5/proyecto_pelis/src/w3-project_SQL/data/film.csv')

df_ori
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1    A Astounding Epistle of a Database Administrat...          2006
# 2    A Astounding Reflection of a Lumberjack And a ...          2006
# 3    A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4    A Fast-Paced Documentary of a Pastry Chef And ...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# ...

# %%
df = df_ori.copy()

df
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1    A Astounding Epistle of a Database Administrat...          2006
# 2    A Astounding Reflection of a Lumberjack And a ...          2006
# 3    A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4    A Fast-Paced Documentary of a Pastry Chef And ...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# ...

# %%
df.isna().all(axis=0).all()
# Out:
# False

# %%
df.isna().any().any()
# Out:
# True

# %%
filas_duplis = df[['film_id', 'title', 'description', 'release_year', 'language_id', 'original_language_id', 'rental_duration', 'rental_rate', 'length', 'replacement_cost', 'rating', 'special_features', 'last_update']]

# %%
filas_duplis.duplicated().any()
# Out:
# False

# %%
df['original_language_id'].duplicated().any()
# Out:
# True

# %%
df['original_language_id'].fillna('Unknown', inplace=True)

# %%
df['original_language_id'].duplicated().any()
# Out:
# True

# %%
df.original_language_id.isna().sum()
# Out:
# 0

# %%
df
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1    A Astounding Epistle of a Database Administrat...          2006
# 2    A Astounding Reflection of a Lumberjack And a ...          2006
# 3    A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4    A Fast-Paced Documentary of a Pastry Chef And ...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# ...

# %%
#cargarse la columna de original lenguange

# %%
df.drop(columns=['last_update', 'original_language_id',], inplace=True)


df
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1    A Astounding Epistle of a Database Administrat...          2006
# 2    A Astounding Reflection of a Lumberjack And a ...          2006
# 3    A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4    A Fast-Paced Documentary of a Pastry Chef And ...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# ...

# %%
from sqlalchemy import create_engine

# %%
str_conn = f'mysql+pymysql://root:666666@localhost:3306/proyecto_pelis'

cursor = create_engine(str_conn)
print(cursor)
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/proyecto_pelis)

# %%
df.to_sql(name='films_',       # nombre de la tabla
            con=cursor,           # conexion al servidor
            if_exists='replace',  # replace sobreescribe la tabla
            index=True
           )
# Out:
# 1000

# %%
df['language_id'].unique()
# Out:
# array([1])

# %%
df
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1    A Astounding Epistle of a Database Administrat...          2006
# 2    A Astounding Reflection of a Lumberjack And a ...          2006
# 3    A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4    A Fast-Paced Documentary of a Pastry Chef And ...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# ...

# %%
# Assuming df is your DataFrame
df['rental_benefit'] = df['rental_duration'] * df['rental_rate']

# %%
df
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1    A Astounding Epistle of a Database Administrat...          2006
# 2    A Astounding Reflection of a Lumberjack And a ...          2006
# 3    A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4    A Fast-Paced Documentary of a Pastry Chef And ...          2006
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2006
# ...

# %%
df['rental_benefit'].max()
# Out:
# 34.93

# %%
=df['rental_benefit'].nlargest(10)
# Out:
# 69     34.93
# 83     34.93
# 87     34.93
# 91     34.93
# 99     34.93
# 102    34.93
# 132    34.93
# 138    34.93
# 143    34.93
# 164    34.93
# Name: rental_benefit, dtype: float64

# %%
# Assuming df is your DataFrame
profitability_by_title = df.groupby('title')['rental_benefit'].sum().reset_index()

profitability_by_title
# Out:
#                  title  rental_benefit
# 0     ACADEMY DINOSAUR            5.94
# 1       ACE GOLDFINGER           14.97
# 2     ADAPTATION HOLES           20.93
# 3     AFFAIR PREJUDICE           14.95
# 4          AFRICAN EGG           17.94
# ..                 ...             ...
# 995     YOUNG LANGUAGE            5.94
# 996         YOUTH KICK            3.96
# 997       ZHIVAGO CORE            5.94
# 998  ZOOLANDER FICTION           14.95
# 999          ZORRO ARK           14.97
#
# [1000 rows x 2 columns]

# %%
df['title'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: title, Length: 1000, dtype: bool

# %%
df['title'].unique()
# Out:
# array(['ACADEMY DINOSAUR', 'ACE GOLDFINGER', 'ADAPTATION HOLES',
#        'AFFAIR PREJUDICE', 'AFRICAN EGG', 'AGENT TRUMAN',
#        'AIRPLANE SIERRA', 'AIRPORT POLLOCK', 'ALABAMA DEVIL',
#        'ALADDIN CALENDAR', 'ALAMO VIDEOTAPE', 'ALASKA PHANTOM',
#        'ALI FOREVER', 'ALICE FANTASIA', 'ALIEN CENTER', 'ALLEY EVOLUTION',
#        'ALONE TRIP', 'ALTER VICTORY', 'AMADEUS HOLY',
#        'AMELIE HELLFIGHTERS', 'AMERICAN CIRCUS', 'AMISTAD MIDSUMMER',
#        'ANACONDA CONFESSIONS', 'ANALYZE HOOSIERS', 'ANGELS LIFE',
#        'ANNIE IDENTITY', 'ANONYMOUS HUMAN', 'ANTHEM LUKE',
#        'ANTITRUST TOMATOES', 'ANYTHING SAVANNAH', 'APACHE DIVINE',
#        'APOCALYPSE FLAMINGOS', 'APOLLO TEEN', 'ARABIA DOGMA',
#        'ARACHNOPHOBIA ROLLERCOASTER', 'ARGONAUTS TOWN', 'ARIZONA BANG',
#        'ARK RIDGEMONT', 'ARMAGEDDON LOST', 'ARMY FLINTSTONES',
#        'ARSENIC INDEPENDENCE', 'ARTIST COLDBLOODED', 'ATLANTIS CAUSE',
# ...

# %%
df['title'].value_counts(normalize=True)*100
# Out:
# title
# ACADEMY DINOSAUR    0.1
# PERFECT GROOVE      0.1
# PARK CITIZEN        0.1
# PARTY KNOCK         0.1
# PAST SUICIDES       0.1
#                    ...
# FROGMEN BREAKING    0.1
# FRONTIER CABIN      0.1
# FROST HEAD          0.1
# FUGITIVE MAGUIRE    0.1
# ZORRO ARK           0.1
# Name: proportion, Length: 1000, dtype: float64

# %%
rental_benefit=df['rental_benefit'].nlargest(10)

rental_benefit
# Out:
# 69     34.93
# 83     34.93
# 87     34.93
# 91     34.93
# 99     34.93
# 102    34.93
# 132    34.93
# 138    34.93
# 143    34.93
# 164    34.93
# Name: rental_benefit, dtype: float64

# %%
rental_benefit.value_counts(normalize=True)*100
# Out:
# rental_benefit
# 34.93    100.0
# Name: proportion, dtype: float64
